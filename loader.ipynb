# %%
import numpy as np 
import matplotlib.pyplot as plt
import scipy

vs1 = np.loadtxt("signal1.txt")
vs2 = np.loadtxt("signal2.txt")
ts = np.arange(vs1.shape[0])

# plt.plot(ts,vs1)
# plt.plot(ts,vs2)
# plt.show()


# hs1 = np.loadtxt("hilbert1.txt")
# hs2 = np.loadtxt("hilbert2.txt")
# ts = np.arange(hs1.shape[0])

# plt.plot(ts,hs1)
# plt.plot(ts,hs2)
# plt.plot(ts,hs2-hs1)
# plt.show()

# %%
phase = np.loadtxt("phase.txt")
ts = np.arange(phase.shape[0])
plt.plot(ts[:],-phase[:])
plt.show()

print(np.mean(phase[:]))
# Out:
# 1.5677367783203124

# %%
phase = np.loadtxt("phase.txt")
ts = np.arange(phase.shape[0])
plt.plot(ts[:400],phase[:400])
plt.show()

print(np.mean(phase[:400]))
# Out:
# 2.0025102125000003

# %%
h1 = scipy.signal.hilbert(vs1)
h2 = scipy.signal.hilbert(vs2)

# %%
phase = np.unwrap(np.angle(h1) - np.angle(h2))

# %%
ts.shape
# Out:
# (10000,)

# %%
phase = np.loadtxt("phase.txt")
ts = np.arange(phase.shape[0])
plt.scatter(ts[:],-phase[:])
plt.show()

print(np.mean(phase[:]))
# Out:
# 1.5677367783203124

# %%
plt.plot(ts,phase)

# %%
np.mean(phase)
# Out:
# -0.9755740140639518

# %%
a1 = np.sin(10*np.linspace(0,1,1000))
a2 = np.sin(10*np.linspace(0,1,1000) + 1)
t = np.linspace(0,1,1000)

# %%
plt.plot(t,a1)
plt.plot(t,a2)

# %%
ha1 = scipy.signal.hilbert(a1)
ha2 = scipy.signal.hilbert(a2)

# %%
phasea = np.angle(ha1)- np.angle(ha2)

# %%
plt.plot(t,phasea)

# %%
plt.plot(t,np.mod(phasea, 2*np.pi))

# %%
np.mean(phasea)
# Out:
# -0.09584520581116476

# %%
np.mean(np.mod(phasea, 2*np.pi)) - 2*np.pi
# Out:
# -0.9754911488163067

# %%
def wrapToPi(x):
    xwrap = np.remainder(x, 2 * np.pi)
    mask = np.abs(xwrap) > np.pi
    xwrap[mask] -= 2 * np.pi * np.sign(xwrap[mask])
    mask1 = x < 0
    mask2 = np.remainder(x, np.pi) == 0
    mask3 = np.remainder(x, 2 * np.pi) != 0
    xwrap[mask1 & mask2 & mask3] -= 2 * np.pi
    return xwrap

# %%
np.mean(wrapToPi(phasea))
# Out:
# 2.5663859033608625

# %%
np.pi -  (10 - (10 // np.pi) * np.pi)
# Out:
# 2.5663706143591725

# %%
2*3.14159265358979323846
# Out:
# 6.283185307179586
